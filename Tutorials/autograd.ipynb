# %%
# use autograd in pytorch
import torch, torchvision
model = torchvision.models.resnet18(pretrained=True)
data = torch.rand(1, 3, 64, 64) # mean 1 sample, 3channels, 64x64 image
labels = torch.rand(1, 1000)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...

# %%
prediction = model(data)

loss = (prediction - labels).sum()
loss.backward()     # backpropagation for calculate gradient

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
optim.step()
# update model's parameters with SGD optimizer

# %%
# auto_grad
import torch

a = torch.tensor([2., 3.], requires_grad=True)
b = torch.tensor([6., 4.], requires_grad=True)

Q = 3*a**3 - b**2

external_grad = torch.tensor([1., 1.])
Q.backward(gradient=external_grad)

print('9*a**2 == a.grad : ',9*a**2 == a.grad)
print('-2*b == b.grad : ', -2*b == b.grad)
# Out:
# 9*a**2 == a.grad :  tensor([True, True])
# -2*b == b.grad :  tensor([True, True])

# %%
a = torch.tensor([2., 3.])
b = torch.tensor([6., 4.], requires_grad=True)

Q = 3*a**3 - b**2

external_grad = torch.tensor([1., 1.])
Q.backward(gradient=external_grad)

print('9*a**2 == a.grad : ',9*a**2 == a.grad)
print('-2*b == b.grad : ', -2*b == b.grad)
# Out:
# 9*a**2 == a.grad :  False
# -2*b == b.grad :  tensor([True, True])
